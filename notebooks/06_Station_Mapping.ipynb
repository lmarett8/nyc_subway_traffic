# %% [markdown]
# *Note to team* - you may need to install some packages first

# %%
# pip install folium

# %% [markdown]
# ### Import libraries, data and create the dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt

import folium
from folium import plugins

# %%
# download the data
stations = pd.read_csv('https://data.ny.gov/api/views/i9wp-a4ja/rows.csv?accessType=DOWNLOAD&sorting=true')
stations.head()
# Out:
#   Division      Line          Station Name  Station Latitude  \
# 0      IND  Rockaway  Far Rockaway-Mott Av         40.603995
# 1      IND  Rockaway         Beach 25th St         40.600066
# 2      IND  Rockaway         Beach 25th St         40.600066
# 3      IND  Rockaway         Beach 25th St         40.600066
# 4      IND  Rockaway         Beach 36th St         40.595398
#
#    Station Longitude Route1 Route2 Route3 Route4 Route5  ... Free Crossover  \
# 0         -73.755405      A    NaN    NaN    NaN    NaN  ...           True
# 1         -73.761353      A    NaN    NaN    NaN    NaN  ...           True
# 2         -73.761353      A    NaN    NaN    NaN    NaN  ...           True
# 3         -73.761353      A    NaN    NaN    NaN    NaN  ...           True
# 4         -73.768175      A    NaN    NaN    NaN    NaN  ...           True
#
#   North South Street  East West Street  Corner  Entrance Latitude  \
# 0      Beach 22nd St          Mott Ave      SW          40.604657
# 1      Beach 25th St     Rockaway Frwy      NW          40.599708
# 2      Beach 25th St     Rockaway Frwy      SW          40.599427
# 3      Beach 25th St     Rockaway Frwy      SW          40.599670
# 4         Beach 36th      Edgemere Ave      NE          40.595445
#
#    Entrance Longitude         Station Location        Entrance Location  \
# 0          -73.754178  (40.603995, -73.755405)  (40.604657, -73.754178)
# 1          -73.761959  (40.600066, -73.761353)  (40.599708, -73.761959)
# 2          -73.761807  (40.600066, -73.761353)  (40.599427, -73.761807)
# 3          -73.761596  (40.600066, -73.761353)   (40.59967, -73.761596)
# 4          -73.768313  (40.595398, -73.768175)  (40.595445, -73.768313)
#
#           entrance_georeference          station_georeference
# 0  POINT (-73.754178 40.604657)  POINT (-73.755405 40.603995)
# 1  POINT (-73.761959 40.599708)  POINT (-73.761353 40.600066)
# 2  POINT (-73.761807 40.599427)  POINT (-73.761353 40.600066)
# 3   POINT (-73.761596 40.59967)  POINT (-73.761353 40.600066)
# 4  POINT (-73.768313 40.595445)  POINT (-73.768175 40.595398)
#
# [5 rows x 34 columns]

# %%
# add 34th St-Herald Square station manually since it is not present in this dataset
stations = stations.append({'Station Name': '34th St-Herald Sq', 'Station Latitude': 40.7501, 'Station Longitude': -73.9881}, ignore_index = True)
# Out:
# /var/folders/lz/08gb56690psggb6cznf0xhwh0000gn/T/ipykernel_95161/3616062942.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stations = stations.append({'Station Name': '34th St-Herald Sq', 'Station Latitude': 40.7501, 'Station Longitude': -73.9881}, ignore_index = True)

# %%
# eliminate unnecessary rows
station_locations = stations.drop(columns = stations.columns[5:], axis = 1).groupby('Station Name').mean()

# %%
station_locations.head()
# Out:
#                              Station Latitude  Station Longitude
# Station Name
# 103rd St                            40.781165         -73.929092
# 104th St-102nd St                   40.695178         -73.844330
# 104th St-Oxford Av                  40.681711         -73.837683
# 110th St                            40.795020         -73.944250
# 110th St-Central Park North         40.799075         -73.951822

# %% [markdown]
# ### Basic scatter plot of all NYC stations

# %%
plt.scatter(x=station_locations['Station Longitude'], y=station_locations['Station Latitude'])
plt.show();

# %% [markdown]
# ### Creating our empty map with folium
# Source: https://www.kaggle.com/code/subinium/how-to-use-folium-geospatial-data/notebook

# %%
# this is the code for creating the map starting at a desired latitude/longitude - needed whenever creating a new map
# could also use coordinates for NYC: 40.7128 (N), -74.0060 (W)

empty_map = folium.Map(location=[station_locations['Station Latitude'].mean(), station_locations['Station Longitude'].mean()], tiles = 'Stamen Terrain', zoom_start=12, control_scale=True)

# %%
empty_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8aa1dddc6fbd3e74e2d3bee62063384 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8aa1dddc6fbd3e74e2d3bee62063384&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c8aa1dddc6fbd3e74e2d3bee62063384 = L.map(
#                 &quot;map_c8aa1dddc6fbd3e74e2d3bee62063384&quot;,
#                 {
#                     center: [40.73089985085596, -73.92936458554998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#
#
#
#             var tile_layer_e9dc5062057b425d2c84c66c1ea3d579 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Creating a map of all of the stations

# %%
for index, location_info in station_locations.iterrows():
    folium.Marker([location_info["Station Latitude"], location_info["Station Longitude"]], tooltip = index).add_to(empty_map)   ## removed argument <popup=location_info["Name"]>

# %%
station_map = empty_map

# resetting the empty map
empty_map = folium.Map(location=[station_locations['Station Latitude'].mean(), station_locations['Station Longitude'].mean()], tiles = 'Stamen Terrain', zoom_start=12, control_scale=True)

# %%
station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8aa1dddc6fbd3e74e2d3bee62063384 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8aa1dddc6fbd3e74e2d3bee62063384&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c8aa1dddc6fbd3e74e2d3bee62063384 = L.map(
#                 &quot;map_c8aa1dddc6fbd3e74e2d3bee62063384&quot;,
#                 {
#                     center: [40.73089985085596, -73.92936458554998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#
#
#
#             var tile_layer_e9dc5062057b425d2c84c66c1ea3d579 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             var marker_81ca4b418c316cb94423cb1ec38ecd84 = L.marker(
#                 [40.78116516666667, -73.92909208333333],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_81ca4b418c316cb94423cb1ec38ecd84.bindTooltip(
#                 `&lt;div&gt;
#                      103rd St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b6cf2cb72a869dc8cb32c801e5283dbf = L.marker(
#                 [40.695178, -73.84433],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_b6cf2cb72a869dc8cb32c801e5283dbf.bindTooltip(
#                 `&lt;div&gt;
#                      104th St-102nd St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10943222d81065f3eca15d74fda9e4a9 = L.marker(
#                 [40.681711, -73.837683],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_10943222d81065f3eca15d74fda9e4a9.bindTooltip(
#                 `&lt;div&gt;
#                      104th St-Oxford Av
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ef55f5a1e2426721d236c7775ed32770 = L.marker(
#                 [40.79502, -73.94425],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_ef55f5a1e2426721d236c7775ed32770.bindTooltip(
#                 `&lt;div&gt;
#                      110th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8e64c183a451b06cb8ab5175dae93276 = L.marker(
#                 [40.799075, -73.951822],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_8e64c183a451b06cb8ab5175dae93276.bindTooltip(
#                 `&lt;div&gt;
#                      110th St-Central Park North
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b083439483f60914390fea1b23bbf686 = L.marker(
#                 [40.7300052, -73.8477384],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_b083439483f60914390fea1b23bbf686.bindTooltip(
#                 `&lt;div&gt;
#                      111th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9e5be4604810ea34f37c575dc12f77a0 = L.marker(
#                 [40.684331, -73.832163],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_9e5be4604810ea34f37c575dc12f77a0.bindTooltip(
#                 `&lt;div&gt;
#                      111th St-Greenwood Av
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f0e4cedc7ae4bcf4657cc86b59bced4f = L.marker(
#                 [40.801937333333335, -73.948708],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_f0e4cedc7ae4bcf4657cc86b59bced4f.bindTooltip(
#                 `&lt;div&gt;
#                      116th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7e28dbc86a51dc0dcf05d808bb306dca = L.marker(
#                 [40.807722, -73.96411],
#                 {}
#             ).addTo(map_c8aa1dddc6fbd3e74e2d3bee62063384);
#
#
#             marker_7e28dbc86a51dc0dcf05d808bb306dca.bindTooltip(
#                 `&lt;div&gt;
#                      116th St-Columbia University
#                  &lt;/div&gt;`,
#                 {&quot;

# %% [markdown]
# ### Creating a dynamic cluster map

# %%
plugins.MarkerCluster(station_locations).add_to(empty_map)

# %%
cluster_map = empty_map

# resetting the empty map
empty_map = folium.Map(location=[station_locations['Station Latitude'].mean(), station_locations['Station Longitude'].mean()], tiles = 'Stamen Terrain', zoom_start=12, control_scale=True)

# %%
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_904dbe1806c189fa84fbbfea299ef75b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_904dbe1806c189fa84fbbfea299ef75b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_904dbe1806c189fa84fbbfea299ef75b = L.map(
#                 &quot;map_904dbe1806c189fa84fbbfea299ef75b&quot;,
#                 {
#                     center: [40.73089985085596, -73.92936458554998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_904dbe1806c189fa84fbbfea299ef75b);
#
#
#
#
#
#             var tile_layer_deff531adf2a42ffc9eeb639fa2c20a6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_904dbe1806c189fa84fbbfea299ef75b);
#
#
#             var marker_cluster_1ec716d09333b2744b014f0fa9f68c12 = L.markerClusterGroup(
#                 {}
#             );
#             map_904dbe1806c189fa84fbbfea299ef75b.addLayer(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_d4708d5967c2a14b57ccdcf895108544 = L.marker(
#                 [40.78116516666667, -73.92909208333333],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_3d0924ac237baad580d8269074ebec09 = L.marker(
#                 [40.695178, -73.84433],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_d3bb54e1d20e2db4c9da7f18ee4dd4b4 = L.marker(
#                 [40.681711, -73.837683],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_1985d518d6934f8c39f643a3913759a0 = L.marker(
#                 [40.79502, -73.94425],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_d736e1f9968e13a5dc952d04f694be99 = L.marker(
#                 [40.799075, -73.951822],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_0548f6a985b53e3e8f4f62e7a94d7c57 = L.marker(
#                 [40.7300052, -73.8477384],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_57253f7dbcb3f5c1a5b30885962c625e = L.marker(
#                 [40.684331, -73.832163],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_0e4828963ea2b673a010f5608c382695 = L.marker(
#                 [40.801937333333335, -73.948708],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_aa9dcbf2890379dbd65f9b23a4195789 = L.marker(
#                 [40.807722, -73.96411],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_24e4272ced0694d971120ab9bba7f72d = L.marker(
#                 [40.700492, -73.828294],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_b35f4ce24b250a32fa20fb3ecc7b4010 = L.marker(
#                 [40.80950968421053, -73.94828926315789],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_db31cd589611773897fcb192ea3dd0b8 = L.marker(
#                 [40.816428, -73.9448974],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_bdc42d4afcad4ed431437a44bf838676 = L.marker(
#                 [40.822008, -73.953676],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_45cee1594e295e02c3387251c32a9636 = L.marker(
#                 [40.813224, -73.929849],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);
#
#
#             var marker_999d9244817932967f56a6817f9fd887 = L.marker(
#                 [40.810476, -73.926138],
#                 {}
#             ).addTo(marker_cluster_1ec716d09333b2744b014f0fa9f68c12);

# %% [markdown]
# ### Creating maps focused on our target stations

# %%
# our stations of focus as they are labeled in the latitude/longitude data set - can easily add more if needed
highest_traffic_list = ['34th St',
                        'Grand Central-42nd St',
                        '34th St-Herald Sq',
                        '42nd St',
                        '23rd St',
                        '86th St',
                        'Times Square-42nd St',
                        'Fulton St',
                        '125th St',
                        '14th St-Union Square'
                       ]

# made separate dataframes for target and non-target stations
highest_traffic_stations = station_locations[station_locations.index.isin(highest_traffic_list)]
other_stations = station_locations[~station_locations.index.isin(highest_traffic_list)]

# %% [markdown]
# #### Map of only the target stations

# %%
for index, location_info in highest_traffic_stations.iterrows():
    folium.Marker([location_info["Station Latitude"], location_info["Station Longitude"]], tooltip = index, icon = folium.Icon(color = 'red')).add_to(empty_map)

popular_station_map = empty_map

# resetting the empty map
empty_map = folium.Map(location=[station_locations['Station Latitude'].mean(), station_locations['Station Longitude'].mean()], tiles = 'Stamen Terrain', zoom_start=12, control_scale=True)
popular_station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a88dba724548235d5122b7c0fc5216f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a88dba724548235d5122b7c0fc5216f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a88dba724548235d5122b7c0fc5216f4 = L.map(
#                 &quot;map_a88dba724548235d5122b7c0fc5216f4&quot;,
#                 {
#                     center: [40.73089985085596, -73.92936458554998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#
#
#
#             var tile_layer_4e4098db6dbd53fe592bcd4bdccadf06 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#             var marker_bf2ddd388808462c750a9fcc3b0d65a1 = L.marker(
#                 [40.80950968421053, -73.94828926315789],
#                 {}
#             ).addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#             var icon_631db1cf9397fe6d514f1343dc1fd7e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf2ddd388808462c750a9fcc3b0d65a1.setIcon(icon_631db1cf9397fe6d514f1343dc1fd7e4);
#
#
#             marker_bf2ddd388808462c750a9fcc3b0d65a1.bindTooltip(
#                 `&lt;div&gt;
#                      125th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1e5cbd967303b5bfbc7ebe62f0ef169e = L.marker(
#                 [40.734673, -73.989951],
#                 {}
#             ).addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#             var icon_4105b8d6bb18638bf18af7e2120b0919 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1e5cbd967303b5bfbc7ebe62f0ef169e.setIcon(icon_4105b8d6bb18638bf18af7e2120b0919);
#
#
#             marker_1e5cbd967303b5bfbc7ebe62f0ef169e.bindTooltip(
#                 `&lt;div&gt;
#                      14th St-Union Square
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0ade36f9a9eae1d49faa2590fea52fea = L.marker(
#                 [40.74283785, -73.99244475],
#                 {}
#             ).addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#             var icon_346f709b88289b8d3119bf96aa6d2270 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ade36f9a9eae1d49faa2590fea52fea.setIcon(icon_346f709b88289b8d3119bf96aa6d2270);
#
#
#             marker_0ade36f9a9eae1d49faa2590fea52fea.bindTooltip(
#                 `&lt;div&gt;
#                      23rd St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a9ae7a0d0e1ecc88dfe82413de9b271f = L.marker(
#                 [40.7508817804878, -73.99087592682926],
#                 {}
#             ).addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#             var icon_88759c5e2babd351d0fe2ec621d79d37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9ae7a0d0e1ecc88dfe82413de9b271f.setIcon(icon_88759c5e2babd351d0fe2ec621d79d37);
#
#
#             marker_a9ae7a0d0e1ecc88dfe82413de9b271f.bindTooltip(
#                 `&lt;div&gt;
#                      34th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4fa2f10e8a691f447832e51c9899330 = L.marker(
#                 [40.7501, -73.9881],
#                 {}
#             ).addTo(map_a88dba724548235d5122b7c0fc5216f4);
#
#
#             var icon_a907e52df9371ae2326866202c659d35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;i

# %% [markdown]
# #### Map of all stations with the important stations highlighted

# %%
for index, location_info in highest_traffic_stations.iterrows():
    folium.Marker([location_info["Station Latitude"], location_info["Station Longitude"]], tooltip = index, icon = folium.Icon(color = 'red')).add_to(empty_map)

for index, location_info in other_stations.iterrows():
    folium.Marker([location_info["Station Latitude"], location_info["Station Longitude"]]).add_to(empty_map)

highlighted_station_map = empty_map

# resetting the empty map
empty_map = folium.Map(location=[station_locations['Station Latitude'].mean(), station_locations['Station Longitude'].mean()], tiles = 'Stamen Terrain', zoom_start=12, control_scale=True)

highlighted_station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ceaaf0e94cc75f4ddbbc2983ca77d1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ceaaf0e94cc75f4ddbbc2983ca77d1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2ceaaf0e94cc75f4ddbbc2983ca77d1c = L.map(
#                 &quot;map_2ceaaf0e94cc75f4ddbbc2983ca77d1c&quot;,
#                 {
#                     center: [40.73089985085596, -73.92936458554998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#
#
#
#             var tile_layer_802c027300d23dc135c8490bf3754e41 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#             var marker_f58266c10a1cb93c5bcf6a4732bb8c40 = L.marker(
#                 [40.80950968421053, -73.94828926315789],
#                 {}
#             ).addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#             var icon_615920136d44592ca2fa5fd4a4dccea3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f58266c10a1cb93c5bcf6a4732bb8c40.setIcon(icon_615920136d44592ca2fa5fd4a4dccea3);
#
#
#             marker_f58266c10a1cb93c5bcf6a4732bb8c40.bindTooltip(
#                 `&lt;div&gt;
#                      125th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eb009af04e96dfc4b9be83c1017a8609 = L.marker(
#                 [40.734673, -73.989951],
#                 {}
#             ).addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#             var icon_3eed291a78dc0ebfab6426e545712f5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eb009af04e96dfc4b9be83c1017a8609.setIcon(icon_3eed291a78dc0ebfab6426e545712f5f);
#
#
#             marker_eb009af04e96dfc4b9be83c1017a8609.bindTooltip(
#                 `&lt;div&gt;
#                      14th St-Union Square
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_44f758aa5c674513cd5d30ab34174e28 = L.marker(
#                 [40.74283785, -73.99244475],
#                 {}
#             ).addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#             var icon_88d2f0dfcf73b90ad20e0606c85ff7a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44f758aa5c674513cd5d30ab34174e28.setIcon(icon_88d2f0dfcf73b90ad20e0606c85ff7a5);
#
#
#             marker_44f758aa5c674513cd5d30ab34174e28.bindTooltip(
#                 `&lt;div&gt;
#                      23rd St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_65ea9b005e426917a227b7767878e70b = L.marker(
#                 [40.7508817804878, -73.99087592682926],
#                 {}
#             ).addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#             var icon_6f16a77132254b1f806d20a8ec3402c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_65ea9b005e426917a227b7767878e70b.setIcon(icon_6f16a77132254b1f806d20a8ec3402c2);
#
#
#             marker_65ea9b005e426917a227b7767878e70b.bindTooltip(
#                 `&lt;div&gt;
#                      34th St
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4bc3d86e051395275fc055d6e9362ea = L.marker(
#                 [40.7501, -73.9881],
#                 {}
#             ).addTo(map_2ceaaf0e94cc75f4ddbbc2983ca77d1c);
#
#
#             var icon_d7f2b151e281d7629ff728936f070d03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;i
